# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = '/Users/vinhdao/Documents/Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Create a subset

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# ...

# %% [markdown]
# ## Grouping Data with pandas

# %%
df.groupby('product_name')

# %%
# Performing a single aggregation

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %% [markdown]
# Here, the groupby() function is being assigned to the df dataframe. This creates the pandas object for “department_id.” Onto this resulting object, the agg() function is applied. The agg() function will return the mean of the given column, in this case, “order_number.” Once executed, you should see something like this:

# %%
# Perform aggregation without using agg function

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.562844
# 2     17.518895
# 3     16.907152
# 4     17.537934
# 5     14.894521
# 6     16.658449
# 7     17.072954
# 8     14.942021
# 9     15.447580
# 10    18.681852
# 11    15.352278
# 12    14.327957
# 13    16.578690
# 14    16.666369
# 15    16.153766
# 16    17.768070
# 17    15.602964
# 18    19.674252
# 19    16.924344
# 20    16.292631
# 21    25.535596
# Name: order_number, dtype: float64

# %% [markdown]
# ### Note:
#
# Remember the key difference in syntax between the two methods: when using agg(), put the column you want to aggregate inside the parentheses of the agg() function as an argument. When using mean() (or any other standard aggregation function), simply index the column with square brackets, then follow it with the function you want to use after the dot.

# %%
# Performing multiple aggregation

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.562844   1  99
# 2                17.518895   1  96
# 3                16.907152   1  99
# 4                17.537934   1  99
# 5                14.894521   1  99
# 6                16.658449   1  99
# 7                17.072954   1  99
# 8                14.942021   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.352278   1  99
# 12               14.327957   1  99
# 13               16.578690   1  99
# 14               16.666369   1  99
# 15               16.153766   1  99
# 16               17.768070   1  99
# 17               15.602964   1  99
# 18               19.674252   1  99
# 19               16.924344   1  99
# 20               16.292631   1  99
# 21               25.535596   1  98

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/jv/pcn4vwxj5lg68vdqcxnmbgv00000gn/T/ipykernel_37307/1681540670.py:1: FutureWarning: The provided callable <function max at 0x108865300> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
# ...

# %%
ords_prods_merge =ords_prods_merge.sort_values(by='max_order', ascending=False)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge.head(100)
# Out:
#           product_id                 product_name  aisle_id  department_id  \
# 30644992       47209         Organic Hass Avocado        24              4
# 23126408       35762  Eggo Cinnamon Toast Waffles        52              1
# 23126406       35762  Eggo Cinnamon Toast Waffles        52              1
# 23126405       35762  Eggo Cinnamon Toast Waffles        52              1
# 13146487       21573      Roasted Pine Nut Hummus        67             20
# ...              ...                          ...       ...            ...
# 13145631       21573      Roasted Pine Nut Hummus        67             20
# 13145377       21573      Roasted Pine Nut Hummus        67             20
# 23127702       35762  Eggo Cinnamon Toast Waffles        52              1
# 23127701       35762  Eggo Cinnamon Toast Waffles        52              1
# 23127700       35762  Eggo Cinnamon Toast Waffles        52              1
#
# ...
